# %%
import os
import numpy as np
from matplotlib import pyplot as plt

from PIL import Image
from collections import Counter
from sklearn.cluster import KMeans

# %matplotlib inline

# %%
# Utility function, rgb to hex
def rgb2hex(rgb):
    hex = "#{:02x}{:02x}{:02x}".format(int(rgb[0]), int(rgb[1]), int(rgb[2]))
    return hex

# %% [markdown]
# # Image color extraction using Scikit Learn
#
# We'll see how simple it is to identify the most important colors in an image using the K Means, unsupervised ML model from the Scikit Learn package.

# %% [markdown]
# ### Step 1: Define some meta variables
#
# You can play around with the following variables to generate different results. `CLUSTERS` is probably the most important one, as it defines the number of colors we'll extract from the image.

# %%
PATH = './sample-image-1.jpg'
WIDTH = 128
HEIGHT = 128
CLUSTERS = 6

# %% [markdown]
# ### Step 2: Open the image using Pillow
#
# We'll use the Pillow library to open and manipulate the image.

# %%
image = Image.open(PATH)

# %%
image.size
# Out:
# (668, 1002)

# %%
print("Loaded {f} image. Size: {s:.2f} KB. Dimensions: ({d})".format(
    f=image.format, s=os.path.getsize(PATH) / 1024, d=image.size))
# Out:
# Loaded JPEG image. Size: 115.93 KB. Dimensions: ((668, 1002))

# %% [markdown]
# ### Step 3: Resize image
#
# The ML model will take considerably longer if the image is large. We'll try to resize it keeping the aspect ratio.

# %%
def calculate_new_size(image):
    if image.width >= image.height:
        wpercent = (WIDTH / float(image.width))
        hsize = int((float(image.height) * float(wpercent)))
        new_width, new_height = WIDTH, hsize
    else:
        hpercent = (HEIGHT / float(image.height))
        wsize = int((float(image.width) * float(hpercent)))
        new_width, new_height = wsize, HEIGHT
    return new_width, new_height

# %%
calculate_new_size(image)
# Out:
# (85, 128)

# %%
new_width, new_height = calculate_new_size(image)

# %%
image.resize((new_width, new_height), Image.ANTIALIAS)
# Out:
# <PIL.Image.Image image mode=RGB size=85x128 at 0x275245934E0>

# %%
image = image.resize((new_width, new_height), Image.ANTIALIAS)

# %% [markdown]
# ### Step 4: Creating the numpy arrays
#
# Our ML Model needs the image as an array of pixels. We explained this in detail in one of [our workshops](https://www.youtube.com/watch?v=2Q4L3MtdAbY).

# %%
img_array = np.array(image)

# %%
img_vector = img_array.reshape((img_array.shape[0] * img_array.shape[1], 3))

# %% [markdown]
# ### Step 5: Create the model and train it
#
# We're ready for the true ML part. We'll create a model using `N` clusters and extract the colors.

# %%
model = KMeans(n_clusters=CLUSTERS)

# %%
labels = model.fit_predict(img_vector)

# %%
label_counts = Counter(labels)

# %%
total_count = sum(label_counts.values())

# %% [markdown]
# These are the colors extracted:

# %%
hex_colors = [
    rgb2hex(center) for center in model.cluster_centers_
]
hex_colors
# Out:
# ['#8f8680', '#cfd5da', '#ce9706', '#524332', '#f9cf7e', '#946b0f']

# %% [markdown]
# And this is the proportion of each color:

# %%
list(zip(hex_colors, list(label_counts.values())))
# Out:
# [('#8f8680', 1192),
#  ('#cfd5da', 3297),
#  ('#ce9706', 1845),
#  ('#524332', 1022),
#  ('#f9cf7e', 2524),
#  ('#946b0f', 1000)]

# %% [markdown]
# ### Final Result:
# We can see now the final result of the color extracted:

# %%
plt.figure(figsize=(14, 8))
plt.subplot(221)
plt.imshow(image)
plt.axis('off')

plt.subplot(222)
plt.pie(label_counts.values(), labels=hex_colors, colors=[color / 255 for color in model.cluster_centers_], startangle=90)
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-047f87b5aa81> in <module>()
#       5
#       6 plt.subplot(222)
# ----> 7 plt.pie(label_counts.values(), labels=hex_colors, colors=[color / 255 for color in model.cluster_centers_], startangle=90)
#       8 plt.axis('equal')
#       9 plt.show()
#
# ~\.conda\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2741         radius=radius, counterclock=counterclock,
#    2742         wedgeprops=wedgeprops, textprops=textprops, center=center,
# -> 2743         frame=frame, rotatelabels=rotatelabels, data=data)
#    2744
#    2745 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~\.conda\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\.conda\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2790         """
#    2791         self.set_aspect('equal')
# -> 2792         x = np.array(x, np.float32)
#    2793
#    2794         sx = x.sum()
#
# TypeError: float() argument must be a string or a number, not 'dict_values'
